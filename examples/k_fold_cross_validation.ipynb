# %%
import sys
import numpy as np
sys.path.append("..")
from msna_file_io import get_dataframes
from msna_pipeline import MSNA_pipeline

# %%
dfs = get_dataframes()
# Out:
#  64%|██████▎   | 28/44 [00:11<00:05,  2.87it/s]
# list index out of range ../MSNAS/MSNA205/MSNA205_rest_burstcomments_downsampled_Emma.txt
#  84%|████████▍ | 37/44 [00:14<00:02,  2.56it/s]
# No bursts found.
# 'NoneType' object is not subscriptable ../MSNAS/MSNA172/MSNA172_rest_burstcomments_downsampled_Emma.txt
# 100%|██████████| 44/44 [00:17<00:00,  2.49it/s]

# %%
pipeline = MSNA_pipeline(verbose=True)

# %%
f1s = pipeline.k_fold_cross_validation(dfs, 10)
print(f1s, np.mean(f1s), np.std(f1s))
# Out:
# Training
# Processing dataframes.
# Processed dataframes, chunking.
# Got chunks, making dataloader.
# Made dataloadder, training CNN.
# /Users/trippdow/anaconda3/envs/health/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/32], Loss: 0.2727
# Epoch [2/32], Loss: 0.2218
# Epoch [3/32], Loss: 0.2013
# Epoch [4/32], Loss: 0.1858
# Epoch [5/32], Loss: 0.1700
# Epoch [6/32], Loss: 0.1579
# Epoch [7/32], Loss: 0.1479
# Epoch [8/32], Loss: 0.1398
# Epoch [9/32], Loss: 0.1325
# Epoch [10/32], Loss: 0.1285
# Epoch [11/32], Loss: 0.1222
# Epoch [12/32], Loss: 0.1172
# Epoch [13/32], Loss: 0.1139
# Epoch [14/32], Loss: 0.1104
# Epoch [15/32], Loss: 0.1077
# Epoch [16/32], Loss: 0.1058
# Epoch [17/32], Loss: 0.1016
# Epoch [18/32], Loss: 0.1002
# Epoch [19/32], Loss: 0.0958
# Epoch [20/32], Loss: 0.0936
# Epoch [21/32], Loss: 0.0912
# Epoch [22/32], Loss: 0.0891
# Epoch [23/32], Loss: 0.0886
# Epoch [24/32], Loss: 0.0855
# Epoch [25/32], Loss: 0.0838
# Epoch [26/32], Loss: 0.0817
# Epoch [27/32], Loss: 0.0842
# Epoch [28/32], Loss: 0.0783
# Epoch [29/32], Loss: 0.0781
# Epoch [30/32], Loss: 0.0795
# Epoch [31/32], Loss: 0.0736
# Epoch [32/32], Loss: 0.0729
# Training complete.
# trained CNN, getting threshold.
# Optimization terminated successfully.
#          Current function value: 0.066551
#          Iterations: 10
#          Function evaluations: 22
# Got threshold, training complete.
# Validating
# F1 for split0: 0.864357403659363
# Current Threshold: 0.9923203125
# Training
# Processing dataframes.
# Processed dataframes, chunking.
# Got chunks, making dataloader.
# Made dataloadder, training CNN.
# /Users/trippdow/anaconda3/envs/health/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/32], Loss: 0.3109
# Epoch [2/32], Loss: 0.2296
# Epoch [3/32], Loss: 0.2171
# Epoch [4/32], Loss: 0.2019
# Epoch [5/32], Loss: 0.1847
# Epoch [6/32], Loss: 0.1697
# Epoch [7/32], Loss: 0.1584
# Epoch [8/32], Loss: 0.1492
# Epoch [9/32], Loss: 0.1436
# Epoch [10/32], Loss: 0.1466
# Epoch [11/32], Loss: 0.1289
# Epoch [12/32], Loss: 0.1259
# Epoch [13/32], Loss: 0.1664
# Epoch [14/32], Loss: 0.1228
# Epoch [15/32], Loss: 0.1357
# Epoch [16/32], Loss: 0.1123
# Epoch [17/32], Loss: 0.1070
# Epoch [18/32], Loss: 0.1185
# Epoch [19/32], Loss: 0.1047
# Epoch [20/32], Loss: 0.1160
# Epoch [21/32], Loss: 0.1096
# Epoch [22/32], Loss: 0.0825
# Epoch [23/32], Loss: 0.0798
# Epoch [24/32], Loss: 0.0778
# Epoch [25/32], Loss: 0.0756
# Epoch [26/32], Loss: 0.0761
# Epoch [27/32], Loss: 0.0742
# Epoch [28/32], Loss: 0.0723
# Epoch [29/32], Loss: 0.0714
# Epoch [30/32], Loss: 0.0709
# Epoch [31/32], Loss: 0.0736
# Epoch [32/32], Loss: 0.0722
# Training complete.
# trained CNN, getting threshold.
