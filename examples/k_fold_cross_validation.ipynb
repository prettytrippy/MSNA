# %%
import sys
import numpy as np
sys.path.append("..")
from msna_file_io import get_dataframes
from msna_pipeline import MSNA_pipeline

# %%
dfs = get_dataframes()
# Out:
#  64%|██████▎   | 28/44 [00:11<00:05,  2.70it/s]
# list index out of range ../MSNAS/MSNA205/MSNA205_rest_burstcomments_downsampled_Emma.txt
#  84%|████████▍ | 37/44 [00:14<00:02,  2.49it/s]
# No bursts found.
# 'NoneType' object is not subscriptable ../MSNAS/MSNA172/MSNA172_rest_burstcomments_downsampled_Emma.txt
# 100%|██████████| 44/44 [00:17<00:00,  2.47it/s]

# %%
pipeline = MSNA_pipeline(verbose=True)

# %%
f1s = pipeline.k_fold_cross_validation(dfs, 10)
print(f1s, np.mean(f1s), np.std(f1s))
# Out:
# Training
# Processing dataframes.
# Processed dataframes, chunking.
# Got chunks, making dataloader.
# Made dataloadder, training CNN.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 f1s = pipeline.k_fold_cross_validation(dfs, 10)
#       2 print(f1s, np.mean(f1s), np.std(f1s))
#
# File ~/Projects/HealthIntelligence/msna/examples/../msna_pipeline.py:346, in MSNA_pipeline.k_fold_cross_validation(self, dfs, k)
#     344 if self.verbose:
#     345     print("Training")
# --> 346 self.train(train_samples)
#     348 if self.verbose:
#     349     print("Validating")
#
# File ~/Projects/HealthIntelligence/msna/examples/../msna_pipeline.py:300, in MSNA_pipeline.train(self, dfs, threshold_train_max_iter, learning_rate, num_epochs)
#     297 if self.verbose:
#     298     print("Made dataloadder, training CNN.")
# --> 300 self.train_cnn(trainloader, num_epochs=num_epochs, learning_rate=learning_rate)
#     301 # self.find_kernel(dfs)
#     303 if self.verbose:
#
# File ~/Projects/HealthIntelligence/msna/examples/../msna_pipeline.py:121, in MSNA_pipeline.train_cnn(self, trainloader, num_epochs, learning_rate)
#     118 for inputs, labels in trainloader:
#     119     # Forward
#     120     optimizer.zero_grad()
# --> 121     outputs = self.cnn(inputs.float())
#     123     # Backward
#     124     loss = criterion(outputs, labels.float().unsqueeze(1))
#
# File ~/anaconda3/envs/health/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/health/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/Projects/HealthIntelligence/msna/examples/../msna_cnn.py:43, in MSNA_CNN.forward(self, x)
#      41 x = self.pool(F.relu(self.bn3(self.conv3(x))))
#      42 x = self.pool(F.relu(self.bn4(self.conv4(x))))
# ---> 43 x = self.pool(F.relu(self.bn5(self.conv5(x))))
#      44 x = self.pool(F.relu(self.bn6(self.conv6(x))))
#      46 # Flatten
#
# File ~/anaconda3/envs/health/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/health/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/health/lib/python3.12/site-packages/torch/nn/modules/conv.py:375, in Conv1d.forward(self, input)
#     374 def forward(self, input: Tensor) -> Tensor:
# --> 375     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/anaconda3/envs/health/lib/python3.12/site-packages/torch/nn/modules/conv.py:370, in Conv1d._conv_forward(self, input, weight, bias)
#     358 if self.padding_mode != "zeros":
#     359     return F.conv1d(
#     360         F.pad(
#     361             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     368         self.groups,
#     369     )
# --> 370 return F.conv1d(
#     371     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     372 )
#
# KeyboardInterrupt:
